# %% [markdown]
# # Creating a page for the tutorial

# %%
pip install -U jupyter-book ghp-import

# %%
# !mkdir potentiometric_map_tutorial
# %cd potentiometric_map_tutorial
# Out:
# /Volumes/Marchezepe/GitHub/potentiometric_map/potentiometric_map_tutorial
# /Volumes/Marchezepe/GitHub/potentiometric_map/.venv/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.

# %%
# Execute no terminal para rodar no local host
jupyter-book init

# %%
# Execute para atualizar e executar no arquivo desejado
jupyter-book build --html

# Acesso via

# %%
# Cria pasta de workflows
mkdir -p .github/workflows
